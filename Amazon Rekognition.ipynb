# %%
# install boto3 

# !pip install boto3 --upgrade
# pip install aws-utils
# pip install aws-python-utils

# %%
# create a bucket on aws 
# upload any image there

# %%
# mention name of image and bucket-name

# %%
import boto3

def detect_labels(photo, bucket):

    client=boto3.client('rekognition')

    response = client.detect_labels(Image={'S3Object':{'Bucket':bucket,'Name':photo}},
        MaxLabels=10)

    print('Detected labels for ' + photo) 
    print()   
    for label in response['Labels']:
        print ("Label: " + label['Name'])
        print ("Confidence: " + str(label['Confidence']))
        print ("Instances:")
        for instance in label['Instances']:
            print ("  Bounding box")
            print ("    Top: " + str(instance['BoundingBox']['Top']))
            print ("    Left: " + str(instance['BoundingBox']['Left']))
            print ("    Width: " +  str(instance['BoundingBox']['Width']))
            print ("    Height: " +  str(instance['BoundingBox']['Height']))
            print ("  Confidence: " + str(instance['Confidence']))
            print()

        print ("Parents:")
        for parent in label['Parents']:
            print ("   " + parent['Name'])
        print ("----------")
        print ()
    return len(response['Labels'])


def main():
    photo='sudhanshu.jpeg'
    bucket='ml-flow01'
    label_count=detect_labels(photo, bucket)
    print("Labels detected: " + str(label_count))


if __name__ == "__main__":
    main()
# Out:
# Detected labels for sudhanshu.jpeg
#
# Label: Face
# Confidence: 99.58039093017578
# Instances:
# Parents:
#    Person
# ----------
#
# Label: Person
# Confidence: 99.58039093017578
# Instances:
#   Bounding box
#     Top: 0.04097750782966614
#     Left: 0.08925311267375946
#     Width: 0.9002822041511536
#     Height: 0.9409720301628113
#   Confidence: 99.0300521850586
#
# Parents:
# ----------
#
# Label: Clothing
# Confidence: 91.0960693359375
# Instances:
# Parents:
# ----------
#
# Label: Lighting
# Confidence: 90.47608184814453
# Instances:
# Parents:
# ----------
#
# Label: Man
# Confidence: 89.4249496459961
# Instances:
# Parents:
#    Person
# ----------
#
# Label: Portrait
# Confidence: 89.2127914428711
# Instances:
# Parents:
#    Face
#    Photography
#    Person
# ----------
#
# Label: Photography
# Confidence: 89.2127914428711
# Instances:
# Parents:
#    Person
# ----------
#
# Label: Chair
# Confidence: 88.6359634399414
# Instances:
# Parents:
# ----------
#
# Label: Head
# Confidence: 84.20128631591797
# Instances:
# Parents:
# ----------
#
# Label: Selfie
# Confidence: 83.95608520507812
# Instances:
# Parents:
#    Portrait
#    Face
#    Photography
#    Person
# ----------
#
# Labels detected: 10
